# %%
# Basic
import os
import numpy as np
import pandas as pd
import urllib.request
import zipfile
import shutil
import random

# visuals
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread
from PIL import Image

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay

# Tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,MaxPooling2D,Dropout,Flatten,BatchNormalization,Conv2D, Input
from tensorflow.keras.callbacks import ReduceLROnPlateau,EarlyStopping
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy
print(tf.config.list_physical_devices('GPU'))

import warnings
warnings.filterwarnings('ignore')
# !nvidia-smi
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Wed Nov  6 09:40:19 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.03                 Driver Version: 566.03         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3070 Ti   WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   39C    P8             16W /  310W |     591MiB /   8192MiB |     22%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      2092    C+G   ...on\wallpaper_engine\wallpaper32.exe      N/A      |
# |    0   N/A  N/A      6508    C+G   ...Programs\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A      7540    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A      8984    C+G   ...64__v826wp6bftszj\TranslucentTB.exe      N/A      |
# |    0   N/A  N/A      9304    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     10068    C+G   ...on\130.0.2849.56\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     10596    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A     11156    C+G   ...Cloudflare WARP\Cloudflare WARP.exe      N/A      |
# |    0   N/A  N/A     12732    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     13168    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     13772    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     14732    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     16012    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Step 1: Download and extract the dataset
data_url = 'https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip'
urllib.request.urlretrieve(data_url, 'D:/IMV/Test Image Classification/kagglecatsanddogs_5340.zip')

# Extract the dataset
local_file = 'D:/IMV/Test Image Classification/kagglecatsanddogs_5340.zip'
with zipfile.ZipFile(local_file, 'r') as zip_ref:
    zip_ref.extractall('D:/IMV/Test Image Classification/data/')

# Define paths for train and test folders
base_dir = 'D:/IMV/Test Image Classification/data/PetImages'
train_dir = 'D:/IMV/Test Image Classification/data/dogs-vs-cats/train'
test_dir = 'D:/IMV/Test Image Classification/data/dogs-vs-cats/test'

# Step 2: Create train and test directories
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Step 3: Split the data and combine cat and dog images
split_ratio = 0.8  # 80% for training, 20% for testing

for category in ['Cat', 'Dog']:
    category_path = os.path.join(base_dir, category)
    images = os.listdir(category_path)
    random.shuffle(images)

    split_index = int(len(images) * split_ratio)

    train_images = images[:split_index]
    test_images = images[split_index:]

    for img in train_images:
        src = os.path.join(category_path, img)
        dst = os.path.join(train_dir, f"{category.lower()}.{img}")
        if os.path.isfile(src):
            shutil.move(src, dst)

    for img in test_images:
        src = os.path.join(category_path, img)
        dst = os.path.join(test_dir, f"{category.lower()}.{img}")
        if os.path.isfile(src):
            shutil.move(src, dst)

print("Dataset split into train and test folders successfully.")
# Out:
# Dataset split into train and test folders successfully.

# %%
# Set the image directory path
image_dir = "D:/IMV/Test Image Classification/data/dogs-vs-cats/train"

# List filenames in the directory
filenames = os.listdir(image_dir)

# Extract labels from filenames
labels = [x.split(".")[0] for x in filenames]

# Create a DataFrame with filenames and labels
data = pd.DataFrame({"filename": filenames, "label": labels})

# Display the first few rows of the DataFrame
data.head()
# Out:
#        filename label
# 0     cat.0.jpg   cat
# 1     cat.1.jpg   cat
# 2    cat.10.jpg   cat
# 3   cat.100.jpg   cat
# 4  cat.1000.jpg   cat

# %%
def visualize_data(data_dir, categories=['cat', 'dog'], num_images=5):
    plt.figure(figsize=(12, 6))

    for i, category in enumerate(categories):
        images = [img for img in os.listdir(data_dir) if img.startswith(category)]
        selected_images = random.sample(images, num_images)
        for j, img_name in enumerate(selected_images):
            img_path = os.path.join(data_dir, img_name)
            img = load_img(img_path, target_size=(150, 150)) 
            img_array = img_to_array(img) / 255.0 

            # Plot image
            plt.subplot(len(categories), num_images, i * num_images + j + 1)
            plt.imshow(img_array)
            plt.axis('off')
            if j == num_images // 2:
                plt.title(category.capitalize())

    plt.tight_layout()
    plt.show()

# Visualize 5 images from each category in the training dataset
train_dir = 'D:/IMV/Test Image Classification/data/dogs-vs-cats/train'
visualize_data(train_dir, num_images=5)

# %%
# Define the base directory
data_dir = 'D:/IMV/Test Image Classification/data/dogs-vs-cats'  # Base directory with combined images
train_dir = os.path.join(data_dir, 'train')

# Collect file paths and labels
file_paths = []
labels = []

# Loop through images in the combined train directory
for img_file in os.listdir(train_dir):
    if img_file.startswith('cat'):
        labels.append('Cat')
    elif img_file.startswith('dog'):
        labels.append('Dog')
    else:
        continue  # Skip any files that do not match expected format
    file_paths.append(os.path.join(train_dir, img_file))

# Create DataFrame
data = pd.DataFrame({'file_path': file_paths, 'label': labels})

# Split data into training (80%) and temp (20%) for test and validation
X_train, X_temp = train_test_split(data, test_size=0.2, stratify=data['label'], random_state=42)

# Split the temp data equally into test (10%) and validation (10%)
X_test, X_val = train_test_split(X_temp, test_size=0.5, stratify=X_temp['label'], random_state=42)

# Print the shape of each split
print('The shape of train data:', X_train.shape)
print('The shape of test data:', X_test.shape)
print('The shape of validation data:', X_val.shape)
# Out:
# The shape of train data: (20000, 2)
# The shape of test data: (2500, 2)
# The shape of validation data: (2500, 2)

# %%
# Function to check if images are valid
def validate_images(df):
    valid_rows = []
    for idx, row in df.iterrows():
        file_path = row['file_path']
        try:
            if file_path.endswith('.db'):
                print(f"Non-image file detected and removed: {file_path}")
                os.remove(file_path)
                continue
            with Image.open(file_path) as img:
                img.verify()  
            valid_rows.append(row) 
        except (IOError, SyntaxError, Image.DecompressionBombError, OSError):
            print(f"Invalid or truncated image file detected and removed: {file_path}")
            os.remove(file_path)  
    return pd.DataFrame(valid_rows) 

# Apply the function to validate and filter out invalid or non-image files
X_train = validate_images(X_train)
X_val = validate_images(X_val)
X_test = validate_images(X_test)

# Re-check the dataset size after cleaning
print("Cleaned dataset sizes:")
print("X_train:", X_train.shape)
print("X_val:", X_val.shape)
print("X_test:", X_test.shape)
# Out:
# Non-image file detected and removed: D:/IMV/Test Image Classification/data/dogs-vs-cats\train\dog.Thumbs.db
# Invalid or truncated image file detected and removed: D:/IMV/Test Image Classification/data/dogs-vs-cats\train\cat.666.jpg
# Cleaned dataset sizes:
# X_train: (19998, 2)
# X_val: (2500, 2)
# X_test: (2500, 2)

# %%
labels = ['Cat', 'Dog']

# Get unique counts for each split
label1, count1 = np.unique(X_train.label, return_counts=True)
label2, count2 = np.unique(X_val.label, return_counts=True)
label3, count3 = np.unique(X_test.label, return_counts=True)

# Create DataFrames for each split
uni1 = pd.DataFrame(data=count1, index=labels, columns=['Count'])
uni2 = pd.DataFrame(data=count2, index=labels, columns=['Count'])
uni3 = pd.DataFrame(data=count3, index=labels, columns=['Count'])

# Set up the figure and style
plt.figure(figsize=(18, 6), dpi=200)
sns.set_style('whitegrid')

# Function to add value labels on top of bars
def add_labels(data, ax):
    for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}',
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center',
                    xytext=(0, 5),
                    textcoords='offset points',
                    fontsize=10, color='black')

# Plot the class distribution in training set
plt.subplot(1, 3, 1)
ax1 = sns.barplot(data=uni1.reset_index(), x='index', y='Count', hue='index', palette='Blues', dodge=False, legend=False, width=0.4)
ax1.set_title('Class Distribution in Training Set', fontsize=15)
ax1.set_xlabel('Labels', fontsize=12)
ax1.set_ylabel('Count', fontsize=12)
add_labels(uni1, ax1)

# Plot the class distribution in validation set
plt.subplot(1, 3, 2)
ax2 = sns.barplot(data=uni2.reset_index(), x='index', y='Count', hue='index', palette='Greens', dodge=False, legend=False, width=0.4)
ax2.set_title('Class Distribution in Validation Set', fontsize=15)
ax2.set_xlabel('Labels', fontsize=12)
ax2.set_ylabel('Count', fontsize=12)
add_labels(uni2, ax2)

# Plot the class distribution in testing set
plt.subplot(1, 3, 3)
ax3 = sns.barplot(data=uni3.reset_index(), x='index', y='Count', hue='index', palette='Oranges', dodge=False, legend=False, width=0.4)
ax3.set_title('Class Distribution in Testing Set', fontsize=15)
ax3.set_xlabel('Labels', fontsize=12)
ax3.set_ylabel('Count', fontsize=12)
add_labels(uni3, ax3)

plt.tight_layout()
plt.show()

# %%
# parameters
image_size = 128
image_channel = 3
bat_size = 32

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                    rotation_range = 15,
                                    horizontal_flip = True,
                                    zoom_range = 0.2,
                                    shear_range = 0.1,
                                    fill_mode = 'reflect',
                                    width_shift_range = 0.1,
                                    height_shift_range = 0.1)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_dataframe(
    X_train,
    directory=None,
    x_col='file_path',
    y_col='label',
    batch_size=bat_size,
    target_size=(image_size, image_size),
    class_mode='binary'
)

val_generator = test_datagen.flow_from_dataframe(
    X_val,
    directory=None,
    x_col='file_path',
    y_col='label',
    batch_size=bat_size,
    target_size=(image_size, image_size),
    class_mode='binary',
    shuffle=False
)

test_generator = test_datagen.flow_from_dataframe(
    X_test,
    directory=None, 
    x_col='file_path',
    y_col='label',
    batch_size=bat_size,
    target_size=(image_size, image_size),
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 19998 validated image filenames belonging to 2 classes.
# Found 2500 validated image filenames belonging to 2 classes.
# Found 2500 validated image filenames belonging to 2 classes.

# %%
model = Sequential()

# Input Layer
model.add(Input(shape=(image_size, image_size, image_channel)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# Block 1
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# Block 2
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# Block 3
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# Fully Connected layers
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# Output layer for binary classification
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (BatchN  (None, 126, 126, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 6, 6, 256)         0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 512)               4719104
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 5,112,001
# Trainable params: 5,110,017
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_binary_accuracy',
                                            patience=10,
                                            factor=0.5,
                                            min_lr = 1e-5,
                                            verbose =1)

early_stoping = EarlyStopping(monitor='val_loss',patience=10,restore_best_weights=True,verbose=1)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=[BinaryAccuracy(), Precision(), Recall()])

# %%
cat_dog = model.fit(train_generator,
                    validation_data = val_generator,
                    callbacks=[early_stoping,learning_rate_reduction],
                    epochs = 100,
                   )
# Out:
# Epoch 1/100
# 625/625 [==============================] - 50s 72ms/step - loss: 0.6719 - binary_accuracy: 0.6462 - precision: 0.6476 - recall: 0.6414 - val_loss: 0.5949 - val_binary_accuracy: 0.6764 - val_precision: 0.7014 - val_recall: 0.6144 - lr: 0.0010
# Epoch 2/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.5332 - binary_accuracy: 0.7310 - precision: 0.7341 - recall: 0.7243 - val_loss: 0.5961 - val_binary_accuracy: 0.7260 - val_precision: 0.9041 - val_recall: 0.5056 - lr: 0.0010
# Epoch 3/100
# 625/625 [==============================] - 45s 71ms/step - loss: 0.4575 - binary_accuracy: 0.7809 - precision: 0.7811 - recall: 0.7806 - val_loss: 0.4735 - val_binary_accuracy: 0.7800 - val_precision: 0.8623 - val_recall: 0.6664 - lr: 0.0010
# Epoch 4/100
# 625/625 [==============================] - 78s 124ms/step - loss: 0.3967 - binary_accuracy: 0.8196 - precision: 0.8180 - recall: 0.8222 - val_loss: 0.3220 - val_binary_accuracy: 0.8648 - val_precision: 0.8707 - val_recall: 0.8568 - lr: 0.0010
# Epoch 5/100
# 625/625 [==============================] - 73s 117ms/step - loss: 0.3551 - binary_accuracy: 0.8403 - precision: 0.8390 - recall: 0.8423 - val_loss: 0.3506 - val_binary_accuracy: 0.8476 - val_precision: 0.8723 - val_recall: 0.8144 - lr: 0.0010
# Epoch 6/100
# 625/625 [==============================] - 45s 71ms/step - loss: 0.3255 - binary_accuracy: 0.8562 - precision: 0.8563 - recall: 0.8561 - val_loss: 0.3018 - val_binary_accuracy: 0.8696 - val_precision: 0.8626 - val_recall: 0.8792 - lr: 0.0010
# Epoch 7/100
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2986 - binary_accuracy: 0.8703 - precision: 0.8658 - recall: 0.8766 - val_loss: 0.3072 - val_binary_accuracy: 0.8748 - val_precision: 0.8168 - val_recall: 0.9664 - lr: 0.0010
# Epoch 8/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.2827 - binary_accuracy: 0.8759 - precision: 0.8753 - recall: 0.8767 - val_loss: 0.2484 - val_binary_accuracy: 0.9012 - val_precision: 0.8779 - val_recall: 0.9320 - lr: 0.0010
# Epoch 9/100
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2755 - binary_accuracy: 0.8816 - precision: 0.8789 - recall: 0.8852 - val_loss: 0.3024 - val_binary_accuracy: 0.8748 - val_precision: 0.8994 - val_recall: 0.8440 - lr: 0.0010
# Epoch 10/100
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2564 - binary_accuracy: 0.8901 - precision: 0.8898 - recall: 0.8905 - val_loss: 0.2555 - val_binary_accuracy: 0.8932 - val_precision: 0.8704 - val_recall: 0.9240 - lr: 0.0010
# Epoch 11/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.2443 - binary_accuracy: 0.8980 - precision: 0.8952 - recall: 0.9016 - val_loss: 0.2089 - val_binary_accuracy: 0.9164 - val_precision: 0.9491 - val_recall: 0.8800 - lr: 0.0010
# Epoch 12/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.2338 - binary_accuracy: 0.9007 - precision: 0.8980 - recall: 0.9041 - val_loss: 0.2213 - val_binary_accuracy: 0.9024 - val_precision: 0.9451 - val_recall: 0.8544 - lr: 0.0010
# Epoch 13/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.2353 - binary_accuracy: 0.9005 - precision: 0.9009 - recall: 0.9001 - val_loss: 0.1905 - val_binary_accuracy: 0.9220 - val_precision: 0.9349 - val_recall: 0.9072 - lr: 0.0010
# Epoch 14/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.2278 - binary_accuracy: 0.9041 - precision: 0.9026 - recall: 0.9061 - val_loss: 0.2344 - val_binary_accuracy: 0.9076 - val_precision: 0.9705 - val_recall: 0.8408 - lr: 0.0010
# Epoch 15/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.2136 - binary_accuracy: 0.9112 - precision: 0.9106 - recall: 0.9120 - val_loss: 0.2418 - val_binary_accuracy: 0.8992 - val_precision: 0.9664 - val_recall: 0.8272 - lr: 0.0010
# Epoch 16/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.2087 - binary_accuracy: 0.9151 - precision: 0.9117 - recall: 0.9193 - val_loss: 0.1598 - val_binary_accuracy: 0.9392 - val_precision: 0.9385 - val_recall: 0.9400 - lr: 0.0010
# Epoch 17/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.2100 - binary_accuracy: 0.9120 - precision: 0.9112 - recall: 0.9131 - val_loss: 0.1450 - val_binary_accuracy: 0.9432 - val_precision: 0.9308 - val_recall: 0.9576 - lr: 0.0010
# Epoch 18/100
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1991 - binary_accuracy: 0.9167 - precision: 0.9150 - recall: 0.9187 - val_loss: 0.1497 - val_binary_accuracy: 0.9428 - val_precision: 0.9556 - val_recall: 0.9288 - lr: 0.0010
# Epoch 19/100
# 625/625 [==============================] - 46s 73ms/step - loss: 0.2012 - binary_accuracy: 0.9174 - precision: 0.9142 - recall: 0.9213 - val_loss: 0.1691 - val_binary_accuracy: 0.9320 - val_precision: 0.9180 - val_recall: 0.9488 - lr: 0.0010
# Epoch 20/100
# 625/625 [==============================] - 45s 71ms/step - loss: 0.1907 - binary_accuracy: 0.9223 - precision: 0.9225 - recall: 0.9220 - val_loss: 0.1751 - val_binary_accuracy: 0.9312 - val_precision: 0.9492 - val_recall: 0.9112 - lr: 0.0010
# Epoch 21/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1902 - binary_accuracy: 0.9219 - precision: 0.9196 - recall: 0.9247 - val_loss: 0.1477 - val_binary_accuracy: 0.9436 - val_precision: 0.9418 - val_recall: 0.9456 - lr: 0.0010
# Epoch 22/100
# 625/625 [==============================] - 46s 73ms/step - loss: 0.1845 - binary_accuracy: 0.9239 - precision: 0.9209 - recall: 0.9275 - val_loss: 0.2326 - val_binary_accuracy: 0.9064 - val_precision: 0.9765 - val_recall: 0.8328 - lr: 0.0010
# Epoch 23/100
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1793 - binary_accuracy: 0.9258 - precision: 0.9224 - recall: 0.9299 - val_loss: 0.1930 - val_binary_accuracy: 0.9240 - val_precision: 0.8991 - val_recall: 0.9552 - lr: 0.0010
# Epoch 24/100
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1826 - binary_accuracy: 0.9257 - precision: 0.9255 - recall: 0.9260 - val_loss: 0.1771 - val_binary_accuracy: 0.9304 - val_precision: 0.9638 - val_recall: 0.8944 - lr: 0.0010
# Epoch 25/100
# 625/625 [==============================] - 46s 73ms/step - loss: 0.1766 - binary_accuracy: 0.9290 - precision: 0.9281 - recall: 0.9301 - val_loss: 0.2090 - val_binary_accuracy: 0.9128 - val_precision: 0.9640 - val_recall: 0.8576 - lr: 0.0010
# Epoch 26/100
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1820 - binary_accuracy: 0.9259 - precision: 0.9255 - recall: 0.9264 - val_loss: 0.1834 - val_binary_accuracy: 0.9236 - val_precision: 0.9657 - val_recall: 0.8784 - lr: 0.0010
# Epoch 27/100
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1706 - binary_accuracy: 0.9320 - precision: 0.9317 - recall: 0.9325 - val_loss: 0.1375 - val_binary_accuracy: 0.9424 - val_precision: 0.9563 - val_recall: 0.9272 - lr: 0.0010
# Epoch 28/100
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1696 - binary_accuracy: 0.9314 - precision: 0.9306 - recall: 0.9324 - val_loss: 0.1671 - val_binary_accuracy: 0.9292 - val_precision: 0.9445 - val_recall: 0.9120 - lr: 0.0010
# Epoch 29/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1665 - binary_accuracy: 0.9317 - precision: 0.9288 - recall: 0.9352 - val_loss: 0.1221 - val_binary_accuracy: 0.9504 - val_precision: 0.9592 - val_recall: 0.9408 - lr: 0.0010
# Epoch 30/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1650 - binary_accuracy: 0.9328 - precision: 0.9324 - recall: 0.9333 - val_loss: 0.1472 - val_binary_accuracy: 0.9456 - val_precision: 0.9665 - val_recall: 0.9232 - lr: 0.0010
# Epoch 31/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1573 - binary_accuracy: 0.9368 - precision: 0.9360 - recall: 0.9378 - val_loss: 0.1543 - val_binary_accuracy: 0.9384 - val_precision: 0.9158 - val_recall: 0.9656 - lr: 0.0010
# Epoch 32/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1662 - binary_accuracy: 0.9314 - precision: 0.9322 - recall: 0.9306 - val_loss: 0.1562 - val_binary_accuracy: 0.9348 - val_precision: 0.9011 - val_recall: 0.9768 - lr: 0.0010
# Epoch 33/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1537 - binary_accuracy: 0.9386 - precision: 0.9358 - recall: 0.9418 - val_loss: 0.1632 - val_binary_accuracy: 0.9296 - val_precision: 0.9769 - val_recall: 0.8800 - lr: 0.0010
# Epoch 34/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1533 - binary_accuracy: 0.9371 - precision: 0.9352 - recall: 0.9393 - val_loss: 0.1187 - val_binary_accuracy: 0.9544 - val_precision: 0.9479 - val_recall: 0.9616 - lr: 0.0010
# Epoch 35/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1528 - binary_accuracy: 0.9378 - precision: 0.9368 - recall: 0.9389 - val_loss: 0.1600 - val_binary_accuracy: 0.9336 - val_precision: 0.9746 - val_recall: 0.8904 - lr: 0.0010
# Epoch 36/100
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1495 - binary_accuracy: 0.9414 - precision: 0.9417 - recall: 0.9412 - val_loss: 0.1361 - val_binary_accuracy: 0.9504 - val_precision: 0.9540 - val_recall: 0.9464 - lr: 0.0010
# Epoch 37/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1465 - binary_accuracy: 0.9416 - precision: 0.9399 - recall: 0.9436 - val_loss: 0.1183 - val_binary_accuracy: 0.9524 - val_precision: 0.9624 - val_recall: 0.9416 - lr: 0.0010
# Epoch 38/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1477 - binary_accuracy: 0.9425 - precision: 0.9418 - recall: 0.9433 - val_loss: 0.1596 - val_binary_accuracy: 0.9384 - val_precision: 0.9692 - val_recall: 0.9056 - lr: 0.0010
# Epoch 39/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1523 - binary_accuracy: 0.9376 - precision: 0.9376 - recall: 0.9377 - val_loss: 0.1392 - val_binary_accuracy: 0.9460 - val_precision: 0.9386 - val_recall: 0.9544 - lr: 0.0010
# Epoch 40/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1470 - binary_accuracy: 0.9387 - precision: 0.9384 - recall: 0.9391 - val_loss: 0.1966 - val_binary_accuracy: 0.9244 - val_precision: 0.9766 - val_recall: 0.8696 - lr: 0.0010
# Epoch 41/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1417 - binary_accuracy: 0.9427 - precision: 0.9426 - recall: 0.9429 - val_loss: 0.1095 - val_binary_accuracy: 0.9540 - val_precision: 0.9595 - val_recall: 0.9480 - lr: 0.0010
# Epoch 42/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1377 - binary_accuracy: 0.9454 - precision: 0.9447 - recall: 0.9462 - val_loss: 0.1205 - val_binary_accuracy: 0.9508 - val_precision: 0.9385 - val_recall: 0.9648 - lr: 0.0010
# Epoch 43/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1387 - binary_accuracy: 0.9427 - precision: 0.9400 - recall: 0.9458 - val_loss: 0.1175 - val_binary_accuracy: 0.9524 - val_precision: 0.9654 - val_recall: 0.9384 - lr: 0.0010
# Epoch 44/100
# 625/625 [==============================] - ETA: 0s - loss: 0.1365 - binary_accuracy: 0.9457 - precision: 0.9447 - recall: 0.9469
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1365 - binary_accuracy: 0.9457 - precision: 0.9447 - recall: 0.9469 - val_loss: 0.2535 - val_binary_accuracy: 0.8964 - val_precision: 0.9246 - val_recall: 0.8632 - lr: 0.0010
# Epoch 45/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1285 - binary_accuracy: 0.9477 - precision: 0.9488 - recall: 0.9466 - val_loss: 0.1163 - val_binary_accuracy: 0.9504 - val_precision: 0.9653 - val_recall: 0.9344 - lr: 5.0000e-04
# Epoch 46/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1171 - binary_accuracy: 0.9534 - precision: 0.9515 - recall: 0.9556 - val_loss: 0.1275 - val_binary_accuracy: 0.9456 - val_precision: 0.9689 - val_recall: 0.9208 - lr: 5.0000e-04
# Epoch 47/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1178 - binary_accuracy: 0.9523 - precision: 0.9493 - recall: 0.9556 - val_loss: 0.1052 - val_binary_accuracy: 0.9588 - val_precision: 0.9629 - val_recall: 0.9544 - lr: 5.0000e-04
# Epoch 48/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1133 - binary_accuracy: 0.9558 - precision: 0.9544 - recall: 0.9574 - val_loss: 0.1093 - val_binary_accuracy: 0.9544 - val_precision: 0.9679 - val_recall: 0.9400 - lr: 5.0000e-04
# Epoch 49/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1135 - binary_accuracy: 0.9533 - precision: 0.9514 - recall: 0.9555 - val_loss: 0.1183 - val_binary_accuracy: 0.9532 - val_precision: 0.9587 - val_recall: 0.9472 - lr: 5.0000e-04
# Epoch 50/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1172 - binary_accuracy: 0.9531 - precision: 0.9527 - recall: 0.9536 - val_loss: 0.1101 - val_binary_accuracy: 0.9560 - val_precision: 0.9597 - val_recall: 0.9520 - lr: 5.0000e-04
# Epoch 51/100
# 625/625 [==============================] - 43s 69ms/step - loss: 0.1084 - binary_accuracy: 0.9560 - precision: 0.9555 - recall: 0.9567 - val_loss: 0.1039 - val_binary_accuracy: 0.9568 - val_precision: 0.9627 - val_recall: 0.9504 - lr: 5.0000e-04
# Epoch 52/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1046 - binary_accuracy: 0.9589 - precision: 0.9575 - recall: 0.9605 - val_loss: 0.0940 - val_binary_accuracy: 0.9648 - val_precision: 0.9724 - val_recall: 0.9568 - lr: 5.0000e-04
# Epoch 53/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0997 - binary_accuracy: 0.9605 - precision: 0.9596 - recall: 0.9616 - val_loss: 0.1143 - val_binary_accuracy: 0.9584 - val_precision: 0.9751 - val_recall: 0.9408 - lr: 5.0000e-04
# Epoch 54/100
# 625/625 [==============================] - 43s 69ms/step - loss: 0.1063 - binary_accuracy: 0.9580 - precision: 0.9584 - recall: 0.9577 - val_loss: 0.0969 - val_binary_accuracy: 0.9636 - val_precision: 0.9596 - val_recall: 0.9680 - lr: 5.0000e-04
# Epoch 55/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1145 - binary_accuracy: 0.9578 - precision: 0.9580 - recall: 0.9576 - val_loss: 0.0990 - val_binary_accuracy: 0.9636 - val_precision: 0.9692 - val_recall: 0.9576 - lr: 5.0000e-04
# Epoch 56/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1043 - binary_accuracy: 0.9609 - precision: 0.9607 - recall: 0.9612 - val_loss: 0.1004 - val_binary_accuracy: 0.9576 - val_precision: 0.9635 - val_recall: 0.9512 - lr: 5.0000e-04
# Epoch 57/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1048 - binary_accuracy: 0.9579 - precision: 0.9566 - recall: 0.9594 - val_loss: 0.1061 - val_binary_accuracy: 0.9584 - val_precision: 0.9712 - val_recall: 0.9448 - lr: 5.0000e-04
# Epoch 58/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1034 - binary_accuracy: 0.9608 - precision: 0.9606 - recall: 0.9611 - val_loss: 0.1066 - val_binary_accuracy: 0.9584 - val_precision: 0.9743 - val_recall: 0.9416 - lr: 5.0000e-04
# Epoch 59/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1072 - binary_accuracy: 0.9583 - precision: 0.9576 - recall: 0.9592 - val_loss: 0.1267 - val_binary_accuracy: 0.9484 - val_precision: 0.9644 - val_recall: 0.9312 - lr: 5.0000e-04
# Epoch 60/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1100 - binary_accuracy: 0.9572 - precision: 0.9574 - recall: 0.9571 - val_loss: 0.0996 - val_binary_accuracy: 0.9632 - val_precision: 0.9595 - val_recall: 0.9672 - lr: 5.0000e-04
# Epoch 61/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1035 - binary_accuracy: 0.9600 - precision: 0.9581 - recall: 0.9622 - val_loss: 0.1041 - val_binary_accuracy: 0.9568 - val_precision: 0.9583 - val_recall: 0.9552 - lr: 5.0000e-04
# Epoch 62/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0969 - binary_accuracy: 0.9624 - precision: 0.9606 - recall: 0.9643
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0969 - binary_accuracy: 0.9624 - precision: 0.9606 - recall: 0.9643 - val_loss: 0.0904 - val_binary_accuracy: 0.9640 - val_precision: 0.9567 - val_recall: 0.9720 - lr: 5.0000e-04
# Epoch 63/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0906 - binary_accuracy: 0.9642 - precision: 0.9614 - recall: 0.9672 - val_loss: 0.0987 - val_binary_accuracy: 0.9604 - val_precision: 0.9675 - val_recall: 0.9528 - lr: 2.5000e-04
# Epoch 64/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0895 - binary_accuracy: 0.9663 - precision: 0.9656 - recall: 0.9670 - val_loss: 0.0950 - val_binary_accuracy: 0.9636 - val_precision: 0.9685 - val_recall: 0.9584 - lr: 2.5000e-04
# Epoch 65/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0889 - binary_accuracy: 0.9658 - precision: 0.9630 - recall: 0.9689 - val_loss: 0.0890 - val_binary_accuracy: 0.9664 - val_precision: 0.9649 - val_recall: 0.9680 - lr: 2.5000e-04
# Epoch 66/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0896 - binary_accuracy: 0.9650 - precision: 0.9630 - recall: 0.9673 - val_loss: 0.1070 - val_binary_accuracy: 0.9588 - val_precision: 0.9689 - val_recall: 0.9480 - lr: 2.5000e-04
# Epoch 67/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.0877 - binary_accuracy: 0.9663 - precision: 0.9663 - recall: 0.9664 - val_loss: 0.0953 - val_binary_accuracy: 0.9632 - val_precision: 0.9700 - val_recall: 0.9560 - lr: 2.5000e-04
# Epoch 68/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0882 - binary_accuracy: 0.9663 - precision: 0.9670 - recall: 0.9657 - val_loss: 0.0958 - val_binary_accuracy: 0.9636 - val_precision: 0.9692 - val_recall: 0.9576 - lr: 2.5000e-04
# Epoch 69/100
# 625/625 [==============================] - 43s 70ms/step - loss: 0.0866 - binary_accuracy: 0.9668 - precision: 0.9657 - recall: 0.9680 - val_loss: 0.0966 - val_binary_accuracy: 0.9620 - val_precision: 0.9646 - val_recall: 0.9592 - lr: 2.5000e-04
# Epoch 70/100
# 625/625 [==============================] - 44s 71ms/step - loss: 0.0836 - binary_accuracy: 0.9678 - precision: 0.9667 - recall: 0.9691 - val_loss: 0.0978 - val_binary_accuracy: 0.9596 - val_precision: 0.9721 - val_recall: 0.9464 - lr: 2.5000e-04
# Epoch 71/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0848 - binary_accuracy: 0.9669 - precision: 0.9667 - recall: 0.9672 - val_loss: 0.1028 - val_binary_accuracy: 0.9588 - val_precision: 0.9767 - val_recall: 0.9400 - lr: 2.5000e-04
# Epoch 72/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0798 - binary_accuracy: 0.9695 - precision: 0.9680 - recall: 0.9711 - val_loss: 0.1042 - val_binary_accuracy: 0.9588 - val_precision: 0.9728 - val_recall: 0.9440 - lr: 2.5000e-04
# Epoch 73/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0811 - binary_accuracy: 0.9694 - precision: 0.9687 - recall: 0.9702 - val_loss: 0.0927 - val_binary_accuracy: 0.9632 - val_precision: 0.9684 - val_recall: 0.9576 - lr: 2.5000e-04
# Epoch 74/100
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0833 - binary_accuracy: 0.9676 - precision: 0.9663 - recall: 0.9690 - val_loss: 0.0983 - val_binary_accuracy: 0.9608 - val_precision: 0.9714 - val_recall: 0.9496 - lr: 2.5000e-04
# Epoch 75/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0800 - binary_accuracy: 0.9689 - precision: 0.9691 - recall: 0.9687Restoring model weights from the end of the best epoch: 65.
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 625/625 [==============================] - 44s 70ms/step - loss: 0.0800 - binary_accuracy: 0.9689 - precision: 0.9691 - recall: 0.9687 - val_loss: 0.0994 - val_binary_accuracy: 0.9612 - val_precision: 0.9668 - val_recall: 0.9552 - lr: 2.5000e-04
# Epoch 75: early stopping

# %%
# plots for accuracy and Loss with epochs

# Setelah pelatihan, konversi training history ke DataFrame
error = pd.DataFrame(cat_dog.history)

# Set up the plot
plt.figure(figsize=(18, 5), dpi=200)
sns.set_style('darkgrid')

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(error['loss'], label='Training Loss', color='blue')
plt.plot(error['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss', fontsize=15)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend()

# Plot Binary Accuracy
plt.subplot(1, 2, 2)
plt.plot(error['binary_accuracy'], label='Training Accuracy', color='blue')
plt.plot(error['val_binary_accuracy'], label='Validation Accuracy', color='orange')
plt.title('Training and Validation Accuracy', fontsize=15)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Evaluasi model pada test set
results = model.evaluate(test_generator)

# Print hasil evaluasi
print(f'Loss: {results[0]}, Binary Accuracy: {results[1]}, Precision: {results[2]}, Recall: {results[3]}')
# Out:
# 79/79 [==============================] - 8s 97ms/step - loss: 0.0870 - binary_accuracy: 0.9616 - precision: 0.9529 - recall: 0.9712
# Loss: 0.08700349181890488, Binary Accuracy: 0.9616000056266785, Precision: 0.952904224395752, Recall: 0.9711999893188477

# %%
# Mendapatkan prediksi untuk test set
predictions = model.predict(test_generator)
binary_predictions = (predictions > 0.5).astype(int).flatten() 

# Dapatkan label sebenarnya dari test set
true_labels = test_generator.classes 

# Buat confusion matrix
cm = confusion_matrix(true_labels, binary_predictions)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
ConfusionMatrixDisplay(cm, display_labels=['Cat', 'Dog']).plot(cmap='Blues')
plt.title('Confusion Matrix for Test Set')
plt.show()
# Out:
# 79/79 [==============================] - 2s 22ms/step

# %%
# Mengambil satu batch dari test_generator
images, labels = next(test_generator)

# Membuat prediksi untuk batch ini
predictions = model.predict(images)
binary_predictions = (predictions > 0.5).astype(int).flatten()

# Menampilkan gambar dan prediksinya
plt.figure(figsize=(12, 12))
for i in range(len(images)):
    plt.subplot(4, 4, i + 1) 
    plt.imshow(images[i])
    plt.axis('off')
    pred_label = 'Dog' if binary_predictions[i] == 1 else 'Cat'
    true_label = 'Dog' if labels[i] == 1 else 'Cat'
    plt.title(f'Pred: {pred_label}\nTrue: {true_label}', color="green" if pred_label == true_label else "red")
    if i == 15: 
        break

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 62ms/step
